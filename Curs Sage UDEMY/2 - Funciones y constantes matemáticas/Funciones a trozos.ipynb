# %%
f = piecewise([((0,1), x^3), ([1,2], x^2), ([-2, 0], -x^2)])

# %%
f
# Out:
# piecewise(x|-->x^3 on (0, 1), x|-->x^2 on [1, 2], x|-->-x^2 on [-2, 0]; x)

# %%
plot(f)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(1/2)
# Out:
# 1/8

# %%
print("RESUMEN FUNCIONES A TROZOS")
print("Primer de tot hem d'assignar un nom a la funció. Llavors direm f = piecewise([  ]) i a dins els claudàtors posarem parèntesis on anirà cada part de la funció. A cada parèntesi hi ha d'haver l'interval i la funció que hi volem")
# Out:
# RESUMEN FUNCIONES A TROZOS
# Primer de tot hem d'assignar un nom a la funció. Llavors direm f = piecewise([  ]) i a dins els claudàtors posarem parèntesis on anirà cada part de la funció. A cada parèntesi hi ha d'haver l'interval i la funció que hi volem
